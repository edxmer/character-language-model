# %%
import sys
import os
sys.path.append(os.path.abspath('../..'))
from src.models.v1 import bigram_network

# %%
network = bigram_network.BigramNetwork("../../src/data/normalized/en_cities.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.7965, grad_fn=<NegBackward0>)
#   1 tensor(3.2857, grad_fn=<NegBackward0>)
#   2 tensor(3.0309, grad_fn=<NegBackward0>)
#   3 tensor(2.9028, grad_fn=<NegBackward0>)
#   4 tensor(2.8258, grad_fn=<NegBackward0>)
# 115 tensor(2.5527, grad_fn=<NegBackward0>)
# 116 tensor(2.5526, grad_fn=<NegBackward0>)
# 117 tensor(2.5526, grad_fn=<NegBackward0>)
# 118 tensor(2.5525, grad_fn=<NegBackward0>)
# 119 tensor(2.5524, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters).replace('<b>', ''))
# Out:
# te
# m
# lladskte
# ckerit bougrrluckentlauwet
# pfa cokhie
# lioraud llle
# chilana
# covet my
# crkenailasadmau es
# nerne
# fallesunngle
# a ugrk
# ast wnon
# wan
# ptowe
# ferfikainont
# pellmmintottsilicflonsobeaumoucalantostthon gortok aioneveta hiviran l
# kqupe
# mily
# frokstosaverty
