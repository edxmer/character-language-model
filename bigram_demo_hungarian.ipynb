# %%
from bigram_model.bgn import BigramNetwork

# %%
network = BigramNetwork("../data/cities_normalized_hungary.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.6397, grad_fn=<NegBackward0>)
#   1 tensor(2.9936, grad_fn=<NegBackward0>)
#   2 tensor(2.7165, grad_fn=<NegBackward0>)
#   3 tensor(2.5548, grad_fn=<NegBackward0>)
#   4 tensor(2.4766, grad_fn=<NegBackward0>)
# 115 tensor(2.2115, grad_fn=<NegBackward0>)
# 116 tensor(2.2170, grad_fn=<NegBackward0>)
# 117 tensor(2.2114, grad_fn=<NegBackward0>)
# 118 tensor(2.2168, grad_fn=<NegBackward0>)
# 119 tensor(2.2112, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>kematujad<b>
# <b>ercr<b>
# <b>baunabovanycelafulikosa<b>
# <b>per<b>
# <b>tes<b>
# <b>is<b>
# <b>shersafelki<b>
# <b>besmatat<b>
# <b>s<b>
# <b>haunyhesacsokiraros<b>
# <b>megetasorocsomrorot<b>
# <b>mikenarvo<b>
# <b>er<b>
# <b>to<b>
# <b>telar<b>
# <b>van<b>
# <b>gorcsonajvamenyazinar<b>
# <b>biszizokulor<b>
# <b>s<b>
# <b>ma<b>
