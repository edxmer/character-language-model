# %%
from bigram_model.bgn import BigramNetwork
# Out:
# /Users/edi/dev/ai/character-language-model/.venv/lib/python3.14/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
network = BigramNetwork("data/cities_normalized_hungary.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.6030, grad_fn=<NegBackward0>)
#   1 tensor(2.9723, grad_fn=<NegBackward0>)
#   2 tensor(2.7013, grad_fn=<NegBackward0>)
#   3 tensor(2.5465, grad_fn=<NegBackward0>)
#   4 tensor(2.4677, grad_fn=<NegBackward0>)
# 115 tensor(2.2134, grad_fn=<NegBackward0>)
# 116 tensor(2.2151, grad_fn=<NegBackward0>)
# 117 tensor(2.2132, grad_fn=<NegBackward0>)
# 118 tensor(2.2149, grad_fn=<NegBackward0>)
# 119 tensor(2.2131, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>recezsa<b>
# <b>tisziskeszscszecs<b>
# <b>bajszataregannajkeverepo<b>
# <b>kaestor<b>
# <b>ngesemezezta<b>
# <b>ks<b>
# <b>szi<b>
# <b>knazsvazesz<b>
# <b>kaloszecsz<b>
# <b>csikord<b>
# <b>bperonaper<b>
# <b>meszhegykisklony<b>
# <b>g<b>
# <b>dor<b>
# <b>tontekisza<b>
# <b>tpiszbanaroro<b>
# <b>hagyyed<b>
# <b>sz<b>
# <b>borprmo<b>
# <b>ha<b>
