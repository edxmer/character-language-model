# %%
from trigram_model.tgn import TrigramNetwork

# %%
network = TrigramNetwork('data/hungarian_cities.csv')

# %%
network.rate = 20

# %%
for i in range(500):
    print(f'{i:5} ', end='')
    network.train()
# Out:
#     0 tensor(5.3988, grad_fn=<NegBackward0>)
#     1 tensor(4.8345, grad_fn=<NegBackward0>)
#     2 tensor(4.5573, grad_fn=<NegBackward0>)
#     3 tensor(4.4017, grad_fn=<NegBackward0>)
#     4 tensor(4.2647, grad_fn=<NegBackward0>)
#     5 tensor(4.1491, grad_fn=<NegBackward0>)
#     6 tensor(4.0430, grad_fn=<NegBackward0>)
#     7 tensor(3.9532, grad_fn=<NegBackward0>)
#     8 tensor(3.8678, grad_fn=<NegBackward0>)
#     9 tensor(3.7955, grad_fn=<NegBackward0>)
#    10 tensor(3.7250, grad_fn=<NegBackward0>)
#    11 tensor(3.6659, grad_fn=<NegBackward0>)
#    12 tensor(3.6068, grad_fn=<NegBackward0>)
#    13 tensor(3.5580, grad_fn=<NegBackward0>)
#    14 tensor(3.5082, grad_fn=<NegBackward0>)
#    15 tensor(3.4677, grad_fn=<NegBackward0>)
#    16 tensor(3.4254, grad_fn=<NegBackward0>)
#    17 tensor(3.3917, grad_fn=<NegBackward0>)
#    18 tensor(3.3555, grad_fn=<NegBackward0>)
#    19 tensor(3.3272, grad_fn=<NegBackward0>)
#    20 tensor(3.2958, grad_fn=<NegBackward0>)
#    21 tensor(3.2718, grad_fn=<NegBackward0>)
#    22 tensor(3.2444, grad_fn=<NegBackward0>)
#    23 tensor(3.2238, grad_fn=<NegBackward0>)
#    24 tensor(3.1995, grad_fn=<NegBackward0>)
#    25 tensor(3.1815, grad_fn=<NegBackward0>)
#    26 tensor(3.1597, grad_fn=<NegBackward0>)
#    27 tensor(3.1440, grad_fn=<NegBackward0>)
#    28 tensor(3.1242, grad_fn=<NegBackward0>)
#    29 tensor(3.1102, grad_fn=<NegBackward0>)
#    30 tensor(3.0921, grad_fn=<NegBackward0>)
#    31 tensor(3.0796, grad_fn=<NegBackward0>)
#    32 tensor(3.0630, grad_fn=<NegBackward0>)
#    33 tensor(3.0516, grad_fn=<NegBackward0>)
#    34 tensor(3.0363, grad_fn=<NegBackward0>)
#    35 tensor(3.0259, grad_fn=<NegBackward0>)
#    36 tensor(3.0116, grad_fn=<NegBackward0>)
#    37 tensor(3.0021, grad_fn=<NegBackward0>)
#    38 tensor(2.9889, grad_fn=<NegBackward0>)
#    39 tensor(2.9801, grad_fn=<NegBackward0>)
#    40 tensor(2.9678, grad_fn=<NegBackward0>)
#    41 tensor(2.9596, grad_fn=<NegBackward0>)
#    42 tensor(2.9481, grad_fn=<NegBackward0>)
#    43 tensor(2.9405, grad_fn=<NegBackward0>)
#    44 tensor(2.9297, grad_fn=<NegBackward0>)
#    45 tensor(2.9226, grad_fn=<NegBackward0>)
#    46 tensor(2.9125, grad_fn=<NegBackward0>)
#    47 tensor(2.9059, grad_fn=<NegBackward0>)
#    48 tensor(2.8963, grad_fn=<NegBackward0>)
#    49 tensor(2.8901, grad_fn=<NegBackward0>)
#    50 tensor(2.8811, grad_fn=<NegBackward0>)
#    51 tensor(2.8753, grad_fn=<NegBackward0>)
#    52 tensor(2.8668, grad_fn=<NegBackward0>)
#    53 tensor(2.8613, grad_fn=<NegBackward0>)
#    54 tensor(2.8533, grad_fn=<NegBackward0>)
#    55 tensor(2.8481, grad_fn=<NegBackward0>)
#    56 tensor(2.8405, grad_fn=<NegBackward0>)
#    57 tensor(2.8355, grad_fn=<NegBackward0>)
#    58 tensor(2.8283, grad_fn=<NegBackward0>)
#    59 tensor(2.8236, grad_fn=<NegBackward0>)
#    60 tensor(2.8168, grad_fn=<NegBackward0>)
#    61 tensor(2.8123, grad_fn=<NegBackward0>)
#    62 tensor(2.8058, grad_fn=<NegBackward0>)
#    63 tensor(2.8016, grad_fn=<NegBackward0>)
#    64 tensor(2.7954, grad_fn=<NegBackward0>)
#    65 tensor(2.7913, grad_fn=<NegBackward0>)
#    66 tensor(2.7855, grad_fn=<NegBackward0>)
#    67 tensor(2.7815, grad_fn=<NegBackward0>)
#    68 tensor(2.7760, grad_fn=<NegBackward0>)
#    69 tensor(2.7722, grad_fn=<NegBackward0>)
#    70 tensor(2.7669, grad_fn=<NegBackward0>)
#    71 tensor(2.7633, grad_fn=<NegBackward0>)
#    72 tensor(2.7583, grad_fn=<NegBackward0>)
#    73 tensor(2.7547, grad_fn=<NegBackward0>)
#    74 tensor(2.7500, grad_fn=<NegBackward0>)
#    75 tensor(2.7466, grad_fn=<NegBackward0>)
#    76 tensor(2.7420, grad_fn=<NegBackward0>)
#    77 tensor(2.7387, grad_fn=<NegBackward0>)
#    78 tensor(2.7344, grad_fn=<NegBackward0>)
#    79 tensor(2.7312, grad_fn=<NegBackward0>)
#    80 tensor(2.7270, grad_fn=<NegBackward0>)
#    81 tensor(2.7239, grad_fn=<NegBackward0>)
#    82 tensor(2.7200, grad_fn=<NegBackward0>)
#    83 tensor(2.7170, grad_fn=<NegBackward0>)
#    84 tensor(2.7132, grad_fn=<NegBackward0>)
#    85 tensor(2.7103, grad_fn=<NegBackward0>)
#    86 tensor(2.7066, grad_fn=<NegBackward0>)
#    87 tensor(2.7038, grad_fn=<NegBackward0>)
#    88 tensor(2.7003, grad_fn=<NegBackward0>)
#    89 tensor(2.6976, grad_fn=<NegBackward0>)
#    90 tensor(2.6943, grad_fn=<NegBackward0>)
#    91 tensor(2.6916, grad_fn=<NegBackward0>)
#    92 tensor(2.6884, grad_fn=<NegBackward0>)
#    93 tensor(2.6858, grad_fn=<NegBackward0>)
#    94 tensor(2.6827, grad_fn=<NegBackward0>)
#    95 tensor(2.6802, grad_fn=<NegBackward0>)
#    96 tensor(2.6773, grad_fn=<NegBackward0>)
#    97 tensor(2.6748, grad_fn=<NegBackward0>)
#    98 tensor(2.6720, grad_fn=<NegBackward0>)
#    99 tensor(2.6696, grad_fn=<NegBackward0>)
#   100 tensor(2.6668, grad_fn=<NegBackward0>)
#   101 tensor(2.6645, grad_fn=<NegBackward0>)
#   102 tensor(2.6619, grad_fn=<NegBackward0>)
#   103 tensor(2.6596, grad_fn=<NegBackward0>)
#   104 tensor(2.6570, grad_fn=<NegBackward0>)
#   105 tensor(2.6548, grad_fn=<NegBackward0>)
#   106 tensor(2.6524, grad_fn=<NegBackward0>)
#   107 tensor(2.6502, grad_fn=<NegBackward0>)
#   108 tensor(2.6478, grad_fn=<NegBackward0>)
#   109 tensor(2.6457, grad_fn=<NegBackward0>)
#   110 tensor(2.6435, grad_fn=<NegBackward0>)
#   111 tensor(2.6414, grad_fn=<NegBackward0>)
#   112 tensor(2.6392, grad_fn=<NegBackward0>)
#   113 tensor(2.6372, grad_fn=<NegBackward0>)
#   114 tensor(2.6350, grad_fn=<NegBackward0>)
#   115 tensor(2.6331, grad_fn=<NegBackward0>)
#   116 tensor(2.6310, grad_fn=<NegBackward0>)
#   117 tensor(2.6291, grad_fn=<NegBackward0>)
#   118 tensor(2.6271, grad_fn=<NegBackward0>)
#   119 tensor(2.6252, grad_fn=<NegBackward0>)
#   120 tensor(2.6233, grad_fn=<NegBackward0>)
#   121 tensor(2.6214, grad_fn=<NegBackward0>)
#   122 tensor(2.6196, grad_fn=<NegBackward0>)
#   123 tensor(2.6178, grad_fn=<NegBackward0>)
#   124 tensor(2.6160, grad_fn=<NegBackward0>)
#   125 tensor(2.6142, grad_fn=<NegBackward0>)
#   126 tensor(2.6124, grad_fn=<NegBackward0>)
#   127 tensor(2.6107, grad_fn=<NegBackward0>)
#   128 tensor(2.6090, grad_fn=<NegBackward0>)
#   129 tensor(2.6073, grad_fn=<NegBackward0>)
#   130 tensor(2.6057, grad_fn=<NegBackward0>)
#   131 tensor(2.6040, grad_fn=<NegBackward0>)
#   132 tensor(2.6024, grad_fn=<NegBackward0>)
#   133 tensor(2.6008, grad_fn=<NegBackward0>)
#   134 tensor(2.5992, grad_fn=<NegBackward0>)
#   135 tensor(2.5977, grad_fn=<NegBackward0>)
#   136 tensor(2.5961, grad_fn=<NegBackward0>)
#   137 tensor(2.5946, grad_fn=<NegBackward0>)
#   138 tensor(2.5931, grad_fn=<NegBackward0>)
#   139 tensor(2.5916, grad_fn=<NegBackward0>)
#   140 tensor(2.5902, grad_fn=<NegBackward0>)
#   141 tensor(2.5887, grad_fn=<NegBackward0>)
#   142 tensor(2.5873, grad_fn=<NegBackward0>)
#   143 tensor(2.5859, grad_fn=<NegBackward0>)
#   144 tensor(2.5845, grad_fn=<NegBackward0>)
#   145 tensor(2.5831, grad_fn=<NegBackward0>)
#   146 tensor(2.5817, grad_fn=<NegBackward0>)
#   147 tensor(2.5803, grad_fn=<NegBackward0>)
#   148 tensor(2.5790, grad_fn=<NegBackward0>)
#   149 tensor(2.5777, grad_fn=<NegBackward0>)
#   150 tensor(2.5764, grad_fn=<NegBackward0>)
#   151 tensor(2.5751, grad_fn=<NegBackward0>)
#   152 tensor(2.5738, grad_fn=<NegBackward0>)
#   153 tensor(2.5725, grad_fn=<NegBackward0>)
#   154 tensor(2.5713, grad_fn=<NegBackward0>)
#   155 tensor(2.5700, grad_fn=<NegBackward0>)
#   156 tensor(2.5688, grad_fn=<NegBackward0>)
#   157 tensor(2.5676, grad_fn=<NegBackward0>)
#   158 tensor(2.5664, grad_fn=<NegBackward0>)
#   159 tensor(2.5652, grad_fn=<NegBackward0>)
#   160 tensor(2.5640, grad_fn=<NegBackward0>)
#   161 tensor(2.5628, grad_fn=<NegBackward0>)
#   162 tensor(2.5617, grad_fn=<NegBackward0>)
#   163 tensor(2.5605, grad_fn=<NegBackward0>)
#   164 tensor(2.5594, grad_fn=<NegBackward0>)
#   165 tensor(2.5583, grad_fn=<NegBackward0>)
#   166 tensor(2.5571, grad_fn=<NegBackward0>)
#   167 tensor(2.5560, grad_fn=<NegBackward0>)
#   168 tensor(2.5550, grad_fn=<NegBackward0>)
#   169 tensor(2.5539, grad_fn=<NegBackward0>)
#   170 tensor(2.5528, grad_fn=<NegBackward0>)
#   171 tensor(2.5517, grad_fn=<NegBackward0>)
#   172 tensor(2.5507, grad_fn=<NegBackward0>)
#   173 tensor(2.5496, grad_fn=<NegBackward0>)
#   174 tensor(2.5486, grad_fn=<NegBackward0>)
#   175 tensor(2.5476, grad_fn=<NegBackward0>)
#   176 tensor(2.5466, grad_fn=<NegBackward0>)
#   177 tensor(2.5456, grad_fn=<NegBackward0>)
#   178 tensor(2.5446, grad_fn=<NegBackward0>)
#   179 tensor(2.5436, grad_fn=<NegBackward0>)
#   180 tensor(2.5426, grad_fn=<NegBackward0>)
#   181 tensor(2.5417, grad_fn=<NegBackward0>)
#   182 tensor(2.5407, grad_fn=<NegBackward0>)
#   183 tensor(2.5397, grad_fn=<NegBackward0>)
#   184 tensor(2.5388, grad_fn=<NegBackward0>)
#   185 tensor(2.5379, grad_fn=<NegBackward0>)
#   186 tensor(2.5369, grad_fn=<NegBackward0>)
#   187 tensor(2.5360, grad_fn=<NegBackward0>)
#   188 tensor(2.5351, grad_fn=<NegBackward0>)
#   189 tensor(2.5342, grad_fn=<NegBackward0>)
#   190 tensor(2.5333, grad_fn=<NegBackward0>)
#   191 tensor(2.5324, grad_fn=<NegBackward0>)
#   192 tensor(2.5315, grad_fn=<NegBackward0>)
#   193 tensor(2.5307, grad_fn=<NegBackward0>)
#   194 tensor(2.5298, grad_fn=<NegBackward0>)
#   195 tensor(2.5289, grad_fn=<NegBackward0>)
#   196 tensor(2.5281, grad_fn=<NegBackward0>)
#   197 tensor(2.5272, grad_fn=<NegBackward0>)
#   198 tensor(2.5264, grad_fn=<NegBackward0>)
#   199 tensor(2.5256, grad_fn=<NegBackward0>)
#   200 tensor(2.5248, grad_fn=<NegBackward0>)
#   201 tensor(2.5239, grad_fn=<NegBackward0>)
#   202 tensor(2.5231, grad_fn=<NegBackward0>)
#   203 tensor(2.5223, grad_fn=<NegBackward0>)
#   204 tensor(2.5215, grad_fn=<NegBackward0>)
#   205 tensor(2.5207, grad_fn=<NegBackward0>)
#   206 tensor(2.5199, grad_fn=<NegBackward0>)
#   207 tensor(2.5192, grad_fn=<NegBackward0>)
#   208 tensor(2.5184, grad_fn=<NegBackward0>)
#   209 tensor(2.5176, grad_fn=<NegBackward0>)
#   210 tensor(2.5169, grad_fn=<NegBackward0>)
#   211 tensor(2.5161, grad_fn=<NegBackward0>)
#   212 tensor(2.5154, grad_fn=<NegBackward0>)
#   213 tensor(2.5146, grad_fn=<NegBackward0>)
#   214 tensor(2.5139, grad_fn=<NegBackward0>)
#   215 tensor(2.5131, grad_fn=<NegBackward0>)
#   216 tensor(2.5124, grad_fn=<NegBackward0>)
#   217 tensor(2.5117, grad_fn=<NegBackward0>)
#   218 tensor(2.5110, grad_fn=<NegBackward0>)
#   219 tensor(2.5103, grad_fn=<NegBackward0>)
#   220 tensor(2.5095, grad_fn=<NegBackward0>)
#   221 tensor(2.5088, grad_fn=<NegBackward0>)
#   222 tensor(2.5081, grad_fn=<NegBackward0>)
#   223 tensor(2.5075, grad_fn=<NegBackward0>)
#   224 tensor(2.5068, grad_fn=<NegBackward0>)
#   225 tensor(2.5061, grad_fn=<NegBackward0>)
#   226 tensor(2.5054, grad_fn=<NegBackward0>)
#   227 tensor(2.5047, grad_fn=<NegBackward0>)
#   228 tensor(2.5041, grad_fn=<NegBackward0>)
#   229 tensor(2.5034, grad_fn=<NegBackward0>)
#   230 tensor(2.5027, grad_fn=<NegBackward0>)
#   231 tensor(2.5021, grad_fn=<NegBackward0>)
#   232 tensor(2.5014, grad_fn=<NegBackward0>)
#   233 tensor(2.5008, grad_fn=<NegBackward0>)
#   234 tensor(2.5002, grad_fn=<NegBackward0>)
#   235 tensor(2.4995, grad_fn=<NegBackward0>)
#   236 tensor(2.4989, grad_fn=<NegBackward0>)
#   237 tensor(2.4983, grad_fn=<NegBackward0>)
#   238 tensor(2.4976, grad_fn=<NegBackward0>)
#   239 tensor(2.4970, grad_fn=<NegBackward0>)
#   240 tensor(2.4964, grad_fn=<NegBackward0>)
#   241 tensor(2.4958, grad_fn=<NegBackward0>)
#   242 tensor(2.4952, grad_fn=<NegBackward0>)
#   243 tensor(2.4946, grad_fn=<NegBackward0>)
#   244 tensor(2.4940, grad_fn=<NegBackward0>)
#   245 tensor(2.4934, grad_fn=<NegBackward0>)
#   246 tensor(2.4928, grad_fn=<NegBackward0>)
#   247 tensor(2.4922, grad_fn=<NegBackward0>)
#   248 tensor(2.4916, grad_fn=<NegBackward0>)
#   249 tensor(2.4910, grad_fn=<NegBackward0>)
#   250 tensor(2.4905, grad_fn=<NegBackward0>)
#   251 tensor(2.4899, grad_fn=<NegBackward0>)
#   252 tensor(2.4893, grad_fn=<NegBackward0>)
#   253 tensor(2.4888, grad_fn=<NegBackward0>)
#   254 tensor(2.4882, grad_fn=<NegBackward0>)
#   255 tensor(2.4876, grad_fn=<NegBackward0>)
#   256 tensor(2.4871, grad_fn=<NegBackward0>)
#   257 tensor(2.4865, grad_fn=<NegBackward0>)
#   258 tensor(2.4860, grad_fn=<NegBackward0>)
#   259 tensor(2.4854, grad_fn=<NegBackward0>)
#   260 tensor(2.4849, grad_fn=<NegBackward0>)
#   261 tensor(2.4844, grad_fn=<NegBackward0>)
#   262 tensor(2.4838, grad_fn=<NegBackward0>)
#   263 tensor(2.4833, grad_fn=<NegBackward0>)
#   264 tensor(2.4828, grad_fn=<NegBackward0>)
#   265 tensor(2.4822, grad_fn=<NegBackward0>)
#   266 tensor(2.4817, grad_fn=<NegBackward0>)
#   267 tensor(2.4812, grad_fn=<NegBackward0>)
#   268 tensor(2.4807, grad_fn=<NegBackward0>)
#   269 tensor(2.4802, grad_fn=<NegBackward0>)
#   270 tensor(2.4797, grad_fn=<NegBackward0>)
#   271 tensor(2.4791, grad_fn=<NegBackward0>)
#   272 tensor(2.4786, grad_fn=<NegBackward0>)
#   273 tensor(2.4781, grad_fn=<NegBackward0>)
#   274 tensor(2.4776, grad_fn=<NegBackward0>)
#   275 tensor(2.4771, grad_fn=<NegBackward0>)
#   276 tensor(2.4767, grad_fn=<NegBackward0>)
#   277 tensor(2.4762, grad_fn=<NegBackward0>)
#   278 tensor(2.4757, grad_fn=<NegBackward0>)
#   279 tensor(2.4752, grad_fn=<NegBackward0>)
#   280 tensor(2.4747, grad_fn=<NegBackward0>)
#   281 tensor(2.4742, grad_fn=<NegBackward0>)
#   282 tensor(2.4738, grad_fn=<NegBackward0>)
#   283 tensor(2.4733, grad_fn=<NegBackward0>)
#   284 tensor(2.4728, grad_fn=<NegBackward0>)
#   285 tensor(2.4723, grad_fn=<NegBackward0>)
#   286 tensor(2.4719, grad_fn=<NegBackward0>)
#   287 tensor(2.4714, grad_fn=<NegBackward0>)
#   288 tensor(2.4710, grad_fn=<NegBackward0>)
#   289 tensor(2.4705, grad_fn=<NegBackward0>)
#   290 tensor(2.4700, grad_fn=<NegBackward0>)
#   291 tensor(2.4696, grad_fn=<NegBackward0>)
#   292 tensor(2.4691, grad_fn=<NegBackward0>)
#   293 tensor(2.4687, grad_fn=<NegBackward0>)
#   294 tensor(2.4682, grad_fn=<NegBackward0>)
#   295 tensor(2.4678, grad_fn=<NegBackward0>)
#   296 tensor(2.4674, grad_fn=<NegBackward0>)
#   297 tensor(2.4669, grad_fn=<NegBackward0>)
#   298 tensor(2.4665, grad_fn=<NegBackward0>)
#   299 tensor(2.4661, grad_fn=<NegBackward0>)
#   300 tensor(2.4656, grad_fn=<NegBackward0>)
#   301 tensor(2.4652, grad_fn=<NegBackward0>)
#   302 tensor(2.4648, grad_fn=<NegBackward0>)
#   303 tensor(2.4643, grad_fn=<NegBackward0>)
#   304 tensor(2.4639, grad_fn=<NegBackward0>)
#   305 tensor(2.4635, grad_fn=<NegBackward0>)
#   306 tensor(2.4631, grad_fn=<NegBackward0>)
#   307 tensor(2.4627, grad_fn=<NegBackward0>)
#   308 tensor(2.4622, grad_fn=<NegBackward0>)
#   309 tensor(2.4618, grad_fn=<NegBackward0>)
#   310 tensor(2.4614, grad_fn=<NegBackward0>)
#   311 tensor(2.4610, grad_fn=<NegBackward0>)
#   312 tensor(2.4606, grad_fn=<NegBackward0>)
#   313 tensor(2.4602, grad_fn=<NegBackward0>)
#   314 tensor(2.4598, grad_fn=<NegBackward0>)
#   315 tensor(2.4594, grad_fn=<NegBackward0>)
#   316 tensor(2.4590, grad_fn=<NegBackward0>)
#   317 tensor(2.4586, grad_fn=<NegBackward0>)
#   318 tensor(2.4582, grad_fn=<NegBackward0>)
#   319 tensor(2.4578, grad_fn=<NegBackward0>)
#   320 tensor(2.4574, grad_fn=<NegBackward0>)
#   321 tensor(2.4571, grad_fn=<NegBackward0>)
#   322 tensor(2.4567, grad_fn=<NegBackward0>)
#   323 tensor(2.4563, grad_fn=<NegBackward0>)
#   324 tensor(2.4559, grad_fn=<NegBackward0>)
#   325 tensor(2.4555, grad_fn=<NegBackward0>)
#   326 tensor(2.4551, grad_fn=<NegBackward0>)
#   327 tensor(2.4548, grad_fn=<NegBackward0>)
#   328 tensor(2.4544, grad_fn=<NegBackward0>)
#   329 tensor(2.4540, grad_fn=<NegBackward0>)
#   330 tensor(2.4536, grad_fn=<NegBackward0>)
#   331 tensor(2.4533, grad_fn=<NegBackward0>)
#   332 tensor(2.4529, grad_fn=<NegBackward0>)
#   333 tensor(2.4525, grad_fn=<NegBackward0>)
#   334 tensor(2.4522, grad_fn=<NegBackward0>)
#   335 tensor(2.4518, grad_fn=<NegBackward0>)
#   336 tensor(2.4515, grad_fn=<NegBackward0>)
#   337 tensor(2.4511, grad_fn=<NegBackward0>)
#   338 tensor(2.4507, grad_fn=<NegBackward0>)
#   339 tensor(2.4504, grad_fn=<NegBackward0>)
#   340 tensor(2.4500, grad_fn=<NegBackward0>)
#   341 tensor(2.4497, grad_fn=<NegBackward0>)
#   342 tensor(2.4493, grad_fn=<NegBackward0>)
#   343 tensor(2.4490, grad_fn=<NegBackward0>)
#   344 tensor(2.4486, grad_fn=<NegBackward0>)
#   345 tensor(2.4483, grad_fn=<NegBackward0>)
#   346 tensor(2.4479, grad_fn=<NegBackward0>)
#   347 tensor(2.4476, grad_fn=<NegBackward0>)
#   348 tensor(2.4472, grad_fn=<NegBackward0>)
#   349 tensor(2.4469, grad_fn=<NegBackward0>)
#   350 tensor(2.4466, grad_fn=<NegBackward0>)
#   351 tensor(2.4462, grad_fn=<NegBackward0>)
#   352 tensor(2.4459, grad_fn=<NegBackward0>)
#   353 tensor(2.4456, grad_fn=<NegBackward0>)
#   354 tensor(2.4452, grad_fn=<NegBackward0>)
#   355 tensor(2.4449, grad_fn=<NegBackward0>)
#   356 tensor(2.4446, grad_fn=<NegBackward0>)
#   357 tensor(2.4442, grad_fn=<NegBackward0>)
#   358 tensor(2.4439, grad_fn=<NegBackward0>)
#   359 tensor(2.4436, grad_fn=<NegBackward0>)
#   360 tensor(2.4433, grad_fn=<NegBackward0>)
#   361 tensor(2.4429, grad_fn=<NegBackward0>)
#   362 tensor(2.4426, grad_fn=<NegBackward0>)
#   363 tensor(2.4423, grad_fn=<NegBackward0>)
#   364 tensor(2.4420, grad_fn=<NegBackward0>)
#   365 tensor(2.4417, grad_fn=<NegBackward0>)
#   366 tensor(2.4413, grad_fn=<NegBackward0>)
#   367 tensor(2.4410, grad_fn=<NegBackward0>)
#   368 tensor(2.4407, grad_fn=<NegBackward0>)
#   369 tensor(2.4404, grad_fn=<NegBackward0>)
#   370 tensor(2.4401, grad_fn=<NegBackward0>)
#   371 tensor(2.4398, grad_fn=<NegBackward0>)
#   372 tensor(2.4395, grad_fn=<NegBackward0>)
#   373 tensor(2.4392, grad_fn=<NegBackward0>)
#   374 tensor(2.4389, grad_fn=<NegBackward0>)
#   375 tensor(2.4386, grad_fn=<NegBackward0>)
#   376 tensor(2.4383, grad_fn=<NegBackward0>)
#   377 tensor(2.4380, grad_fn=<NegBackward0>)
#   378 tensor(2.4377, grad_fn=<NegBackward0>)
#   379 tensor(2.4374, grad_fn=<NegBackward0>)
#   380 tensor(2.4371, grad_fn=<NegBackward0>)
#   381 tensor(2.4368, grad_fn=<NegBackward0>)
#   382 tensor(2.4365, grad_fn=<NegBackward0>)
#   383 tensor(2.4362, grad_fn=<NegBackward0>)
#   384 tensor(2.4359, grad_fn=<NegBackward0>)
#   385 tensor(2.4356, grad_fn=<NegBackward0>)
#   386 tensor(2.4353, grad_fn=<NegBackward0>)
#   387 tensor(2.4350, grad_fn=<NegBackward0>)
#   388 tensor(2.4347, grad_fn=<NegBackward0>)
#   389 tensor(2.4344, grad_fn=<NegBackward0>)
#   390 tensor(2.4341, grad_fn=<NegBackward0>)
#   391 tensor(2.4339, grad_fn=<NegBackward0>)
#   392 tensor(2.4336, grad_fn=<NegBackward0>)
#   393 tensor(2.4333, grad_fn=<NegBackward0>)
#   394 tensor(2.4330, grad_fn=<NegBackward0>)
#   395 tensor(2.4327, grad_fn=<NegBackward0>)
#   396 tensor(2.4324, grad_fn=<NegBackward0>)
#   397 tensor(2.4322, grad_fn=<NegBackward0>)
#   398 tensor(2.4319, grad_fn=<NegBackward0>)
#   399 tensor(2.4316, grad_fn=<NegBackward0>)
#   400 tensor(2.4313, grad_fn=<NegBackward0>)
#   401 tensor(2.4311, grad_fn=<NegBackward0>)
#   402 tensor(2.4308, grad_fn=<NegBackward0>)
#   403 tensor(2.4305, grad_fn=<NegBackward0>)
#   404 tensor(2.4303, grad_fn=<NegBackward0>)
#   405 tensor(2.4300, grad_fn=<NegBackward0>)
#   406 tensor(2.4297, grad_fn=<NegBackward0>)
#   407 tensor(2.4294, grad_fn=<NegBackward0>)
#   408 tensor(2.4292, grad_fn=<NegBackward0>)
#   409 tensor(2.4289, grad_fn=<NegBackward0>)
#   410 tensor(2.4286, grad_fn=<NegBackward0>)
#   411 tensor(2.4284, grad_fn=<NegBackward0>)
#   412 tensor(2.4281, grad_fn=<NegBackward0>)
#   413 tensor(2.4279, grad_fn=<NegBackward0>)
#   414 tensor(2.4276, grad_fn=<NegBackward0>)
#   415 tensor(2.4273, grad_fn=<NegBackward0>)
#   416 tensor(2.4271, grad_fn=<NegBackward0>)
#   417 tensor(2.4268, grad_fn=<NegBackward0>)
#   418 tensor(2.4266, grad_fn=<NegBackward0>)
#   419 tensor(2.4263, grad_fn=<NegBackward0>)
#   420 tensor(2.4261, grad_fn=<NegBackward0>)
#   421 tensor(2.4258, grad_fn=<NegBackward0>)
#   422 tensor(2.4255, grad_fn=<NegBackward0>)
#   423 tensor(2.4253, grad_fn=<NegBackward0>)
#   424 tensor(2.4250, grad_fn=<NegBackward0>)
#   425 tensor(2.4248, grad_fn=<NegBackward0>)
#   426 tensor(2.4245, grad_fn=<NegBackward0>)
#   427 tensor(2.4243, grad_fn=<NegBackward0>)
#   428 tensor(2.4240, grad_fn=<NegBackward0>)
#   429 tensor(2.4238, grad_fn=<NegBackward0>)
#   430 tensor(2.4235, grad_fn=<NegBackward0>)
#   431 tensor(2.4233, grad_fn=<NegBackward0>)
#   432 tensor(2.4231, grad_fn=<NegBackward0>)
#   433 tensor(2.4228, grad_fn=<NegBackward0>)
#   434 tensor(2.4226, grad_fn=<NegBackward0>)
#   435 tensor(2.4223, grad_fn=<NegBackward0>)
#   436 tensor(2.4221, grad_fn=<NegBackward0>)
#   437 tensor(2.4219, grad_fn=<NegBackward0>)
#   438 tensor(2.4216, grad_fn=<NegBackward0>)
#   439 tensor(2.4214, grad_fn=<NegBackward0>)
#   440 tensor(2.4211, grad_fn=<NegBackward0>)
#   441 tensor(2.4209, grad_fn=<NegBackward0>)
#   442 tensor(2.4207, grad_fn=<NegBackward0>)
#   443 tensor(2.4204, grad_fn=<NegBackward0>)
#   444 tensor(2.4202, grad_fn=<NegBackward0>)
#   445 tensor(2.4200, grad_fn=<NegBackward0>)
#   446 tensor(2.4197, grad_fn=<NegBackward0>)
#   447 tensor(2.4195, grad_fn=<NegBackward0>)
#   448 tensor(2.4193, grad_fn=<NegBackward0>)
#   449 tensor(2.4190, grad_fn=<NegBackward0>)
#   450 tensor(2.4188, grad_fn=<NegBackward0>)
#   451 tensor(2.4186, grad_fn=<NegBackward0>)
#   452 tensor(2.4183, grad_fn=<NegBackward0>)
#   453 tensor(2.4181, grad_fn=<NegBackward0>)
#   454 tensor(2.4179, grad_fn=<NegBackward0>)
#   455 tensor(2.4177, grad_fn=<NegBackward0>)
#   456 tensor(2.4174, grad_fn=<NegBackward0>)
#   457 tensor(2.4172, grad_fn=<NegBackward0>)
#   458 tensor(2.4170, grad_fn=<NegBackward0>)
#   459 tensor(2.4168, grad_fn=<NegBackward0>)
#   460 tensor(2.4166, grad_fn=<NegBackward0>)
#   461 tensor(2.4163, grad_fn=<NegBackward0>)
#   462 tensor(2.4161, grad_fn=<NegBackward0>)
#   463 tensor(2.4159, grad_fn=<NegBackward0>)
#   464 tensor(2.4157, grad_fn=<NegBackward0>)
#   465 tensor(2.4155, grad_fn=<NegBackward0>)
#   466 tensor(2.4152, grad_fn=<NegBackward0>)
#   467 tensor(2.4150, grad_fn=<NegBackward0>)
#   468 tensor(2.4148, grad_fn=<NegBackward0>)
#   469 tensor(2.4146, grad_fn=<NegBackward0>)
#   470 tensor(2.4144, grad_fn=<NegBackward0>)
#   471 tensor(2.4142, grad_fn=<NegBackward0>)
#   472 tensor(2.4139, grad_fn=<NegBackward0>)
#   473 tensor(2.4137, grad_fn=<NegBackward0>)
#   474 tensor(2.4135, grad_fn=<NegBackward0>)
#   475 tensor(2.4133, grad_fn=<NegBackward0>)
#   476 tensor(2.4131, grad_fn=<NegBackward0>)
#   477 tensor(2.4129, grad_fn=<NegBackward0>)
#   478 tensor(2.4127, grad_fn=<NegBackward0>)
#   479 tensor(2.4125, grad_fn=<NegBackward0>)
#   480 tensor(2.4123, grad_fn=<NegBackward0>)
#   481 tensor(2.4121, grad_fn=<NegBackward0>)
#   482 tensor(2.4118, grad_fn=<NegBackward0>)
#   483 tensor(2.4116, grad_fn=<NegBackward0>)
#   484 tensor(2.4114, grad_fn=<NegBackward0>)
#   485 tensor(2.4112, grad_fn=<NegBackward0>)
#   486 tensor(2.4110, grad_fn=<NegBackward0>)
#   487 tensor(2.4108, grad_fn=<NegBackward0>)
#   488 tensor(2.4106, grad_fn=<NegBackward0>)
#   489 tensor(2.4104, grad_fn=<NegBackward0>)
#   490 tensor(2.4102, grad_fn=<NegBackward0>)
#   491 tensor(2.4100, grad_fn=<NegBackward0>)
#   492 tensor(2.4098, grad_fn=<NegBackward0>)
#   493 tensor(2.4096, grad_fn=<NegBackward0>)
#   494 tensor(2.4094, grad_fn=<NegBackward0>)
#   495 tensor(2.4092, grad_fn=<NegBackward0>)
#   496 tensor(2.4090, grad_fn=<NegBackward0>)
#   497 tensor(2.4088, grad_fn=<NegBackward0>)
#   498 tensor(2.4086, grad_fn=<NegBackward0>)
#   499 tensor(2.4084, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>', '<b>']
    while True:
        sample = network.sample (
            network.tokenizer.stoi[letters[-2]],
            network.tokenizer.stoi[letters[-1]]
        )
        letters.append(network.tokenizer.itos[int(sample)])
        if (letters[-1] == '<b>'):
            break
    
    s = ''.join(letters).replace('<b>', '')
    if s != '':
        print(s)
# Out:
# Tis
# PöŐrlá
# Csa
# Baorg
# Bageőkenk
# Halun
# Bacsipki
# OPtteszelsizstetnácselik
# Hós
# Mikv
# Pála
# F
# TLisoond
# Sárd
# Szmocsétgila
# Belőnd
# Kháangy
# MMenc
# Eőd
