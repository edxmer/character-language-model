# %%
from trigram_model.tgn import TrigramNetwork
# Out:
# /Users/edi/dev/ai/character-language-model/.venv/lib/python3.14/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
network = TrigramNetwork('data/hungarian_cities_3000.csv')

# %%
network.rate = 20

# %%
for i in range(500):
    print(f'{i:5} ', end='')
    network.train()
# Out:
#     0 loss: tensor(4.6188, grad_fn=<NegBackward0>)
#     1 loss: tensor(4.5209, grad_fn=<NegBackward0>)
#     2 loss: tensor(4.4319, grad_fn=<NegBackward0>)
#     3 loss: tensor(4.3555, grad_fn=<NegBackward0>)
#     4 loss: tensor(4.2922, grad_fn=<NegBackward0>)
#     5 loss: tensor(4.2379, grad_fn=<NegBackward0>)
#     6 loss: tensor(4.1882, grad_fn=<NegBackward0>)
#     7 loss: tensor(4.1412, grad_fn=<NegBackward0>)
#     8 loss: tensor(4.0961, grad_fn=<NegBackward0>)
#     9 loss: tensor(4.0529, grad_fn=<NegBackward0>)
#    10 loss: tensor(4.0116, grad_fn=<NegBackward0>)
#    11 loss: tensor(3.9722, grad_fn=<NegBackward0>)
#    12 loss: tensor(3.9347, grad_fn=<NegBackward0>)
#    13 loss: tensor(3.8990, grad_fn=<NegBackward0>)
#    14 loss: tensor(3.8651, grad_fn=<NegBackward0>)
#    15 loss: tensor(3.8329, grad_fn=<NegBackward0>)
#    16 loss: tensor(3.8024, grad_fn=<NegBackward0>)
#    17 loss: tensor(3.7733, grad_fn=<NegBackward0>)
#    18 loss: tensor(3.7458, grad_fn=<NegBackward0>)
#    19 loss: tensor(3.7195, grad_fn=<NegBackward0>)
#    20 loss: tensor(3.6945, grad_fn=<NegBackward0>)
#    21 loss: tensor(3.6707, grad_fn=<NegBackward0>)
#    22 loss: tensor(3.6479, grad_fn=<NegBackward0>)
#    23 loss: tensor(3.6261, grad_fn=<NegBackward0>)
#    24 loss: tensor(3.6052, grad_fn=<NegBackward0>)
#    25 loss: tensor(3.5851, grad_fn=<NegBackward0>)
#    26 loss: tensor(3.5659, grad_fn=<NegBackward0>)
#    27 loss: tensor(3.5474, grad_fn=<NegBackward0>)
#    28 loss: tensor(3.5296, grad_fn=<NegBackward0>)
#    29 loss: tensor(3.5125, grad_fn=<NegBackward0>)
#    30 loss: tensor(3.4960, grad_fn=<NegBackward0>)
#    31 loss: tensor(3.4800, grad_fn=<NegBackward0>)
#    32 loss: tensor(3.4647, grad_fn=<NegBackward0>)
#    33 loss: tensor(3.4498, grad_fn=<NegBackward0>)
#    34 loss: tensor(3.4355, grad_fn=<NegBackward0>)
#    35 loss: tensor(3.4217, grad_fn=<NegBackward0>)
#    36 loss: tensor(3.4083, grad_fn=<NegBackward0>)
#    37 loss: tensor(3.3953, grad_fn=<NegBackward0>)
#    38 loss: tensor(3.3827, grad_fn=<NegBackward0>)
#    39 loss: tensor(3.3705, grad_fn=<NegBackward0>)
#    40 loss: tensor(3.3587, grad_fn=<NegBackward0>)
#    41 loss: tensor(3.3473, grad_fn=<NegBackward0>)
#    42 loss: tensor(3.3362, grad_fn=<NegBackward0>)
#    43 loss: tensor(3.3254, grad_fn=<NegBackward0>)
#    44 loss: tensor(3.3149, grad_fn=<NegBackward0>)
#    45 loss: tensor(3.3047, grad_fn=<NegBackward0>)
#    46 loss: tensor(3.2948, grad_fn=<NegBackward0>)
#    47 loss: tensor(3.2851, grad_fn=<NegBackward0>)
#    48 loss: tensor(3.2757, grad_fn=<NegBackward0>)
#    49 loss: tensor(3.2666, grad_fn=<NegBackward0>)
#    50 loss: tensor(3.2577, grad_fn=<NegBackward0>)
#    51 loss: tensor(3.2490, grad_fn=<NegBackward0>)
#    52 loss: tensor(3.2405, grad_fn=<NegBackward0>)
#    53 loss: tensor(3.2323, grad_fn=<NegBackward0>)
#    54 loss: tensor(3.2242, grad_fn=<NegBackward0>)
#    55 loss: tensor(3.2163, grad_fn=<NegBackward0>)
#    56 loss: tensor(3.2086, grad_fn=<NegBackward0>)
#    57 loss: tensor(3.2011, grad_fn=<NegBackward0>)
#    58 loss: tensor(3.1938, grad_fn=<NegBackward0>)
#    59 loss: tensor(3.1866, grad_fn=<NegBackward0>)
#    60 loss: tensor(3.1796, grad_fn=<NegBackward0>)
#    61 loss: tensor(3.1727, grad_fn=<NegBackward0>)
#    62 loss: tensor(3.1659, grad_fn=<NegBackward0>)
#    63 loss: tensor(3.1594, grad_fn=<NegBackward0>)
#    64 loss: tensor(3.1529, grad_fn=<NegBackward0>)
#    65 loss: tensor(3.1466, grad_fn=<NegBackward0>)
#    66 loss: tensor(3.1404, grad_fn=<NegBackward0>)
#    67 loss: tensor(3.1343, grad_fn=<NegBackward0>)
#    68 loss: tensor(3.1283, grad_fn=<NegBackward0>)
#    69 loss: tensor(3.1225, grad_fn=<NegBackward0>)
#    70 loss: tensor(3.1168, grad_fn=<NegBackward0>)
#    71 loss: tensor(3.1111, grad_fn=<NegBackward0>)
#    72 loss: tensor(3.1056, grad_fn=<NegBackward0>)
#    73 loss: tensor(3.1002, grad_fn=<NegBackward0>)
#    74 loss: tensor(3.0949, grad_fn=<NegBackward0>)
#    75 loss: tensor(3.0896, grad_fn=<NegBackward0>)
#    76 loss: tensor(3.0845, grad_fn=<NegBackward0>)
#    77 loss: tensor(3.0795, grad_fn=<NegBackward0>)
#    78 loss: tensor(3.0745, grad_fn=<NegBackward0>)
#    79 loss: tensor(3.0696, grad_fn=<NegBackward0>)
#    80 loss: tensor(3.0648, grad_fn=<NegBackward0>)
#    81 loss: tensor(3.0601, grad_fn=<NegBackward0>)
#    82 loss: tensor(3.0555, grad_fn=<NegBackward0>)
#    83 loss: tensor(3.0509, grad_fn=<NegBackward0>)
#    84 loss: tensor(3.0464, grad_fn=<NegBackward0>)
#    85 loss: tensor(3.0420, grad_fn=<NegBackward0>)
#    86 loss: tensor(3.0377, grad_fn=<NegBackward0>)
#    87 loss: tensor(3.0334, grad_fn=<NegBackward0>)
#    88 loss: tensor(3.0292, grad_fn=<NegBackward0>)
#    89 loss: tensor(3.0250, grad_fn=<NegBackward0>)
#    90 loss: tensor(3.0209, grad_fn=<NegBackward0>)
#    91 loss: tensor(3.0169, grad_fn=<NegBackward0>)
#    92 loss: tensor(3.0129, grad_fn=<NegBackward0>)
#    93 loss: tensor(3.0090, grad_fn=<NegBackward0>)
#    94 loss: tensor(3.0052, grad_fn=<NegBackward0>)
#    95 loss: tensor(3.0014, grad_fn=<NegBackward0>)
#    96 loss: tensor(2.9976, grad_fn=<NegBackward0>)
#    97 loss: tensor(2.9939, grad_fn=<NegBackward0>)
#    98 loss: tensor(2.9903, grad_fn=<NegBackward0>)
#    99 loss: tensor(2.9867, grad_fn=<NegBackward0>)
#   100 loss: tensor(2.9831, grad_fn=<NegBackward0>)
#   101 loss: tensor(2.9796, grad_fn=<NegBackward0>)
#   102 loss: tensor(2.9762, grad_fn=<NegBackward0>)
#   103 loss: tensor(2.9728, grad_fn=<NegBackward0>)
#   104 loss: tensor(2.9694, grad_fn=<NegBackward0>)
#   105 loss: tensor(2.9661, grad_fn=<NegBackward0>)
#   106 loss: tensor(2.9628, grad_fn=<NegBackward0>)
#   107 loss: tensor(2.9596, grad_fn=<NegBackward0>)
#   108 loss: tensor(2.9564, grad_fn=<NegBackward0>)
#   109 loss: tensor(2.9533, grad_fn=<NegBackward0>)
#   110 loss: tensor(2.9501, grad_fn=<NegBackward0>)
#   111 loss: tensor(2.9471, grad_fn=<NegBackward0>)
#   112 loss: tensor(2.9440, grad_fn=<NegBackward0>)
#   113 loss: tensor(2.9410, grad_fn=<NegBackward0>)
#   114 loss: tensor(2.9381, grad_fn=<NegBackward0>)
#   115 loss: tensor(2.9351, grad_fn=<NegBackward0>)
#   116 loss: tensor(2.9322, grad_fn=<NegBackward0>)
#   117 loss: tensor(2.9294, grad_fn=<NegBackward0>)
#   118 loss: tensor(2.9266, grad_fn=<NegBackward0>)
#   119 loss: tensor(2.9238, grad_fn=<NegBackward0>)
#   120 loss: tensor(2.9210, grad_fn=<NegBackward0>)
#   121 loss: tensor(2.9183, grad_fn=<NegBackward0>)
#   122 loss: tensor(2.9156, grad_fn=<NegBackward0>)
#   123 loss: tensor(2.9129, grad_fn=<NegBackward0>)
#   124 loss: tensor(2.9103, grad_fn=<NegBackward0>)
#   125 loss: tensor(2.9077, grad_fn=<NegBackward0>)
#   126 loss: tensor(2.9051, grad_fn=<NegBackward0>)
#   127 loss: tensor(2.9025, grad_fn=<NegBackward0>)
#   128 loss: tensor(2.9000, grad_fn=<NegBackward0>)
#   129 loss: tensor(2.8975, grad_fn=<NegBackward0>)
#   130 loss: tensor(2.8950, grad_fn=<NegBackward0>)
#   131 loss: tensor(2.8926, grad_fn=<NegBackward0>)
#   132 loss: tensor(2.8902, grad_fn=<NegBackward0>)
#   133 loss: tensor(2.8878, grad_fn=<NegBackward0>)
#   134 loss: tensor(2.8854, grad_fn=<NegBackward0>)
#   135 loss: tensor(2.8831, grad_fn=<NegBackward0>)
#   136 loss: tensor(2.8807, grad_fn=<NegBackward0>)
#   137 loss: tensor(2.8784, grad_fn=<NegBackward0>)
#   138 loss: tensor(2.8762, grad_fn=<NegBackward0>)
#   139 loss: tensor(2.8739, grad_fn=<NegBackward0>)
#   140 loss: tensor(2.8717, grad_fn=<NegBackward0>)
#   141 loss: tensor(2.8695, grad_fn=<NegBackward0>)
#   142 loss: tensor(2.8673, grad_fn=<NegBackward0>)
#   143 loss: tensor(2.8651, grad_fn=<NegBackward0>)
#   144 loss: tensor(2.8630, grad_fn=<NegBackward0>)
#   145 loss: tensor(2.8609, grad_fn=<NegBackward0>)
#   146 loss: tensor(2.8588, grad_fn=<NegBackward0>)
#   147 loss: tensor(2.8567, grad_fn=<NegBackward0>)
#   148 loss: tensor(2.8546, grad_fn=<NegBackward0>)
#   149 loss: tensor(2.8526, grad_fn=<NegBackward0>)
#   150 loss: tensor(2.8506, grad_fn=<NegBackward0>)
#   151 loss: tensor(2.8486, grad_fn=<NegBackward0>)
#   152 loss: tensor(2.8466, grad_fn=<NegBackward0>)
#   153 loss: tensor(2.8446, grad_fn=<NegBackward0>)
#   154 loss: tensor(2.8427, grad_fn=<NegBackward0>)
#   155 loss: tensor(2.8407, grad_fn=<NegBackward0>)
#   156 loss: tensor(2.8388, grad_fn=<NegBackward0>)
#   157 loss: tensor(2.8369, grad_fn=<NegBackward0>)
#   158 loss: tensor(2.8350, grad_fn=<NegBackward0>)
#   159 loss: tensor(2.8332, grad_fn=<NegBackward0>)
#   160 loss: tensor(2.8313, grad_fn=<NegBackward0>)
#   161 loss: tensor(2.8295, grad_fn=<NegBackward0>)
#   162 loss: tensor(2.8277, grad_fn=<NegBackward0>)
#   163 loss: tensor(2.8259, grad_fn=<NegBackward0>)
#   164 loss: tensor(2.8241, grad_fn=<NegBackward0>)
#   165 loss: tensor(2.8223, grad_fn=<NegBackward0>)
#   166 loss: tensor(2.8206, grad_fn=<NegBackward0>)
#   167 loss: tensor(2.8189, grad_fn=<NegBackward0>)
#   168 loss: tensor(2.8171, grad_fn=<NegBackward0>)
#   169 loss: tensor(2.8154, grad_fn=<NegBackward0>)
#   170 loss: tensor(2.8137, grad_fn=<NegBackward0>)
#   171 loss: tensor(2.8121, grad_fn=<NegBackward0>)
#   172 loss: tensor(2.8104, grad_fn=<NegBackward0>)
#   173 loss: tensor(2.8087, grad_fn=<NegBackward0>)
#   174 loss: tensor(2.8071, grad_fn=<NegBackward0>)
#   175 loss: tensor(2.8055, grad_fn=<NegBackward0>)
#   176 loss: tensor(2.8039, grad_fn=<NegBackward0>)
#   177 loss: tensor(2.8023, grad_fn=<NegBackward0>)
#   178 loss: tensor(2.8007, grad_fn=<NegBackward0>)
#   179 loss: tensor(2.7991, grad_fn=<NegBackward0>)
#   180 loss: tensor(2.7975, grad_fn=<NegBackward0>)
#   181 loss: tensor(2.7960, grad_fn=<NegBackward0>)
#   182 loss: tensor(2.7945, grad_fn=<NegBackward0>)
#   183 loss: tensor(2.7929, grad_fn=<NegBackward0>)
#   184 loss: tensor(2.7914, grad_fn=<NegBackward0>)
#   185 loss: tensor(2.7899, grad_fn=<NegBackward0>)
#   186 loss: tensor(2.7884, grad_fn=<NegBackward0>)
#   187 loss: tensor(2.7870, grad_fn=<NegBackward0>)
#   188 loss: tensor(2.7855, grad_fn=<NegBackward0>)
#   189 loss: tensor(2.7840, grad_fn=<NegBackward0>)
#   190 loss: tensor(2.7826, grad_fn=<NegBackward0>)
#   191 loss: tensor(2.7812, grad_fn=<NegBackward0>)
#   192 loss: tensor(2.7797, grad_fn=<NegBackward0>)
#   193 loss: tensor(2.7783, grad_fn=<NegBackward0>)
#   194 loss: tensor(2.7769, grad_fn=<NegBackward0>)
#   195 loss: tensor(2.7755, grad_fn=<NegBackward0>)
#   196 loss: tensor(2.7742, grad_fn=<NegBackward0>)
#   197 loss: tensor(2.7728, grad_fn=<NegBackward0>)
#   198 loss: tensor(2.7714, grad_fn=<NegBackward0>)
#   199 loss: tensor(2.7701, grad_fn=<NegBackward0>)
#   200 loss: tensor(2.7687, grad_fn=<NegBackward0>)
#   201 loss: tensor(2.7674, grad_fn=<NegBackward0>)
#   202 loss: tensor(2.7661, grad_fn=<NegBackward0>)
#   203 loss: tensor(2.7648, grad_fn=<NegBackward0>)
#   204 loss: tensor(2.7635, grad_fn=<NegBackward0>)
#   205 loss: tensor(2.7622, grad_fn=<NegBackward0>)
#   206 loss: tensor(2.7609, grad_fn=<NegBackward0>)
#   207 loss: tensor(2.7596, grad_fn=<NegBackward0>)
#   208 loss: tensor(2.7584, grad_fn=<NegBackward0>)
#   209 loss: tensor(2.7571, grad_fn=<NegBackward0>)
#   210 loss: tensor(2.7559, grad_fn=<NegBackward0>)
#   211 loss: tensor(2.7546, grad_fn=<NegBackward0>)
#   212 loss: tensor(2.7534, grad_fn=<NegBackward0>)
#   213 loss: tensor(2.7522, grad_fn=<NegBackward0>)
#   214 loss: tensor(2.7509, grad_fn=<NegBackward0>)
#   215 loss: tensor(2.7497, grad_fn=<NegBackward0>)
#   216 loss: tensor(2.7485, grad_fn=<NegBackward0>)
#   217 loss: tensor(2.7473, grad_fn=<NegBackward0>)
#   218 loss: tensor(2.7462, grad_fn=<NegBackward0>)
#   219 loss: tensor(2.7450, grad_fn=<NegBackward0>)
#   220 loss: tensor(2.7438, grad_fn=<NegBackward0>)
#   221 loss: tensor(2.7427, grad_fn=<NegBackward0>)
#   222 loss: tensor(2.7415, grad_fn=<NegBackward0>)
#   223 loss: tensor(2.7404, grad_fn=<NegBackward0>)
#   224 loss: tensor(2.7392, grad_fn=<NegBackward0>)
#   225 loss: tensor(2.7381, grad_fn=<NegBackward0>)
#   226 loss: tensor(2.7370, grad_fn=<NegBackward0>)
#   227 loss: tensor(2.7359, grad_fn=<NegBackward0>)
#   228 loss: tensor(2.7348, grad_fn=<NegBackward0>)
#   229 loss: tensor(2.7337, grad_fn=<NegBackward0>)
#   230 loss: tensor(2.7326, grad_fn=<NegBackward0>)
#   231 loss: tensor(2.7315, grad_fn=<NegBackward0>)
#   232 loss: tensor(2.7304, grad_fn=<NegBackward0>)
#   233 loss: tensor(2.7293, grad_fn=<NegBackward0>)
#   234 loss: tensor(2.7283, grad_fn=<NegBackward0>)
#   235 loss: tensor(2.7272, grad_fn=<NegBackward0>)
#   236 loss: tensor(2.7261, grad_fn=<NegBackward0>)
#   237 loss: tensor(2.7251, grad_fn=<NegBackward0>)
#   238 loss: tensor(2.7241, grad_fn=<NegBackward0>)
#   239 loss: tensor(2.7230, grad_fn=<NegBackward0>)
#   240 loss: tensor(2.7220, grad_fn=<NegBackward0>)
#   241 loss: tensor(2.7210, grad_fn=<NegBackward0>)
#   242 loss: tensor(2.7200, grad_fn=<NegBackward0>)
#   243 loss: tensor(2.7189, grad_fn=<NegBackward0>)
#   244 loss: tensor(2.7179, grad_fn=<NegBackward0>)
#   245 loss: tensor(2.7169, grad_fn=<NegBackward0>)
#   246 loss: tensor(2.7160, grad_fn=<NegBackward0>)
#   247 loss: tensor(2.7150, grad_fn=<NegBackward0>)
#   248 loss: tensor(2.7140, grad_fn=<NegBackward0>)
#   249 loss: tensor(2.7130, grad_fn=<NegBackward0>)
#   250 loss: tensor(2.7121, grad_fn=<NegBackward0>)
#   251 loss: tensor(2.7111, grad_fn=<NegBackward0>)
#   252 loss: tensor(2.7101, grad_fn=<NegBackward0>)
#   253 loss: tensor(2.7092, grad_fn=<NegBackward0>)
#   254 loss: tensor(2.7082, grad_fn=<NegBackward0>)
#   255 loss: tensor(2.7073, grad_fn=<NegBackward0>)
#   256 loss: tensor(2.7064, grad_fn=<NegBackward0>)
#   257 loss: tensor(2.7054, grad_fn=<NegBackward0>)
#   258 loss: tensor(2.7045, grad_fn=<NegBackward0>)
#   259 loss: tensor(2.7036, grad_fn=<NegBackward0>)
#   260 loss: tensor(2.7027, grad_fn=<NegBackward0>)
#   261 loss: tensor(2.7018, grad_fn=<NegBackward0>)
#   262 loss: tensor(2.7009, grad_fn=<NegBackward0>)
#   263 loss: tensor(2.7000, grad_fn=<NegBackward0>)
#   264 loss: tensor(2.6991, grad_fn=<NegBackward0>)
#   265 loss: tensor(2.6982, grad_fn=<NegBackward0>)
#   266 loss: tensor(2.6973, grad_fn=<NegBackward0>)
#   267 loss: tensor(2.6964, grad_fn=<NegBackward0>)
#   268 loss: tensor(2.6956, grad_fn=<NegBackward0>)
#   269 loss: tensor(2.6947, grad_fn=<NegBackward0>)
#   270 loss: tensor(2.6938, grad_fn=<NegBackward0>)
#   271 loss: tensor(2.6930, grad_fn=<NegBackward0>)
#   272 loss: tensor(2.6921, grad_fn=<NegBackward0>)
#   273 loss: tensor(2.6913, grad_fn=<NegBackward0>)
#   274 loss: tensor(2.6904, grad_fn=<NegBackward0>)
#   275 loss: tensor(2.6896, grad_fn=<NegBackward0>)
#   276 loss: tensor(2.6887, grad_fn=<NegBackward0>)
#   277 loss: tensor(2.6879, grad_fn=<NegBackward0>)
#   278 loss: tensor(2.6871, grad_fn=<NegBackward0>)
#   279 loss: tensor(2.6863, grad_fn=<NegBackward0>)
#   280 loss: tensor(2.6854, grad_fn=<NegBackward0>)
#   281 loss: tensor(2.6846, grad_fn=<NegBackward0>)
#   282 loss: tensor(2.6838, grad_fn=<NegBackward0>)
#   283 loss: tensor(2.6830, grad_fn=<NegBackward0>)
#   284 loss: tensor(2.6822, grad_fn=<NegBackward0>)
#   285 loss: tensor(2.6814, grad_fn=<NegBackward0>)
#   286 loss: tensor(2.6806, grad_fn=<NegBackward0>)
#   287 loss: tensor(2.6798, grad_fn=<NegBackward0>)
#   288 loss: tensor(2.6790, grad_fn=<NegBackward0>)
#   289 loss: tensor(2.6783, grad_fn=<NegBackward0>)
#   290 loss: tensor(2.6775, grad_fn=<NegBackward0>)
#   291 loss: tensor(2.6767, grad_fn=<NegBackward0>)
#   292 loss: tensor(2.6759, grad_fn=<NegBackward0>)
#   293 loss: tensor(2.6752, grad_fn=<NegBackward0>)
#   294 loss: tensor(2.6744, grad_fn=<NegBackward0>)
#   295 loss: tensor(2.6737, grad_fn=<NegBackward0>)
#   296 loss: tensor(2.6729, grad_fn=<NegBackward0>)
#   297 loss: tensor(2.6722, grad_fn=<NegBackward0>)
#   298 loss: tensor(2.6714, grad_fn=<NegBackward0>)
#   299 loss: tensor(2.6707, grad_fn=<NegBackward0>)
#   300 loss: tensor(2.6699, grad_fn=<NegBackward0>)
#   301 loss: tensor(2.6692, grad_fn=<NegBackward0>)
#   302 loss: tensor(2.6685, grad_fn=<NegBackward0>)
#   303 loss: tensor(2.6677, grad_fn=<NegBackward0>)
#   304 loss: tensor(2.6670, grad_fn=<NegBackward0>)
#   305 loss: tensor(2.6663, grad_fn=<NegBackward0>)
#   306 loss: tensor(2.6656, grad_fn=<NegBackward0>)
#   307 loss: tensor(2.6649, grad_fn=<NegBackward0>)
#   308 loss: tensor(2.6642, grad_fn=<NegBackward0>)
#   309 loss: tensor(2.6634, grad_fn=<NegBackward0>)
#   310 loss: tensor(2.6627, grad_fn=<NegBackward0>)
#   311 loss: tensor(2.6620, grad_fn=<NegBackward0>)
#   312 loss: tensor(2.6613, grad_fn=<NegBackward0>)
#   313 loss: tensor(2.6607, grad_fn=<NegBackward0>)
#   314 loss: tensor(2.6600, grad_fn=<NegBackward0>)
#   315 loss: tensor(2.6593, grad_fn=<NegBackward0>)
#   316 loss: tensor(2.6586, grad_fn=<NegBackward0>)
#   317 loss: tensor(2.6579, grad_fn=<NegBackward0>)
#   318 loss: tensor(2.6572, grad_fn=<NegBackward0>)
#   319 loss: tensor(2.6566, grad_fn=<NegBackward0>)
#   320 loss: tensor(2.6559, grad_fn=<NegBackward0>)
#   321 loss: tensor(2.6552, grad_fn=<NegBackward0>)
#   322 loss: tensor(2.6546, grad_fn=<NegBackward0>)
#   323 loss: tensor(2.6539, grad_fn=<NegBackward0>)
#   324 loss: tensor(2.6532, grad_fn=<NegBackward0>)
#   325 loss: tensor(2.6526, grad_fn=<NegBackward0>)
#   326 loss: tensor(2.6519, grad_fn=<NegBackward0>)
#   327 loss: tensor(2.6513, grad_fn=<NegBackward0>)
#   328 loss: tensor(2.6506, grad_fn=<NegBackward0>)
#   329 loss: tensor(2.6500, grad_fn=<NegBackward0>)
#   330 loss: tensor(2.6493, grad_fn=<NegBackward0>)
#   331 loss: tensor(2.6487, grad_fn=<NegBackward0>)
#   332 loss: tensor(2.6481, grad_fn=<NegBackward0>)
#   333 loss: tensor(2.6474, grad_fn=<NegBackward0>)
#   334 loss: tensor(2.6468, grad_fn=<NegBackward0>)
#   335 loss: tensor(2.6462, grad_fn=<NegBackward0>)
#   336 loss: tensor(2.6456, grad_fn=<NegBackward0>)
#   337 loss: tensor(2.6449, grad_fn=<NegBackward0>)
#   338 loss: tensor(2.6443, grad_fn=<NegBackward0>)
#   339 loss: tensor(2.6437, grad_fn=<NegBackward0>)
#   340 loss: tensor(2.6431, grad_fn=<NegBackward0>)
#   341 loss: tensor(2.6425, grad_fn=<NegBackward0>)
#   342 loss: tensor(2.6419, grad_fn=<NegBackward0>)
#   343 loss: tensor(2.6413, grad_fn=<NegBackward0>)
#   344 loss: tensor(2.6407, grad_fn=<NegBackward0>)
#   345 loss: tensor(2.6401, grad_fn=<NegBackward0>)
#   346 loss: tensor(2.6395, grad_fn=<NegBackward0>)
#   347 loss: tensor(2.6389, grad_fn=<NegBackward0>)
#   348 loss: tensor(2.6383, grad_fn=<NegBackward0>)
#   349 loss: tensor(2.6377, grad_fn=<NegBackward0>)
#   350 loss: tensor(2.6371, grad_fn=<NegBackward0>)
#   351 loss: tensor(2.6365, grad_fn=<NegBackward0>)
#   352 loss: tensor(2.6359, grad_fn=<NegBackward0>)
#   353 loss: tensor(2.6354, grad_fn=<NegBackward0>)
#   354 loss: tensor(2.6348, grad_fn=<NegBackward0>)
#   355 loss: tensor(2.6342, grad_fn=<NegBackward0>)
#   356 loss: tensor(2.6336, grad_fn=<NegBackward0>)
#   357 loss: tensor(2.6331, grad_fn=<NegBackward0>)
#   358 loss: tensor(2.6325, grad_fn=<NegBackward0>)
#   359 loss: tensor(2.6319, grad_fn=<NegBackward0>)
#   360 loss: tensor(2.6314, grad_fn=<NegBackward0>)
#   361 loss: tensor(2.6308, grad_fn=<NegBackward0>)
#   362 loss: tensor(2.6303, grad_fn=<NegBackward0>)
#   363 loss: tensor(2.6297, grad_fn=<NegBackward0>)
#   364 loss: tensor(2.6291, grad_fn=<NegBackward0>)
#   365 loss: tensor(2.6286, grad_fn=<NegBackward0>)
#   366 loss: tensor(2.6280, grad_fn=<NegBackward0>)
#   367 loss: tensor(2.6275, grad_fn=<NegBackward0>)
#   368 loss: tensor(2.6270, grad_fn=<NegBackward0>)
#   369 loss: tensor(2.6264, grad_fn=<NegBackward0>)
#   370 loss: tensor(2.6259, grad_fn=<NegBackward0>)
#   371 loss: tensor(2.6253, grad_fn=<NegBackward0>)
#   372 loss: tensor(2.6248, grad_fn=<NegBackward0>)
#   373 loss: tensor(2.6243, grad_fn=<NegBackward0>)
#   374 loss: tensor(2.6237, grad_fn=<NegBackward0>)
#   375 loss: tensor(2.6232, grad_fn=<NegBackward0>)
#   376 loss: tensor(2.6227, grad_fn=<NegBackward0>)
#   377 loss: tensor(2.6222, grad_fn=<NegBackward0>)
#   378 loss: tensor(2.6216, grad_fn=<NegBackward0>)
#   379 loss: tensor(2.6211, grad_fn=<NegBackward0>)
#   380 loss: tensor(2.6206, grad_fn=<NegBackward0>)
#   381 loss: tensor(2.6201, grad_fn=<NegBackward0>)
#   382 loss: tensor(2.6196, grad_fn=<NegBackward0>)
#   383 loss: tensor(2.6190, grad_fn=<NegBackward0>)
#   384 loss: tensor(2.6185, grad_fn=<NegBackward0>)
#   385 loss: tensor(2.6180, grad_fn=<NegBackward0>)
#   386 loss: tensor(2.6175, grad_fn=<NegBackward0>)
#   387 loss: tensor(2.6170, grad_fn=<NegBackward0>)
#   388 loss: tensor(2.6165, grad_fn=<NegBackward0>)
#   389 loss: tensor(2.6160, grad_fn=<NegBackward0>)
#   390 loss: tensor(2.6155, grad_fn=<NegBackward0>)
#   391 loss: tensor(2.6150, grad_fn=<NegBackward0>)
#   392 loss: tensor(2.6145, grad_fn=<NegBackward0>)
#   393 loss: tensor(2.6140, grad_fn=<NegBackward0>)
#   394 loss: tensor(2.6135, grad_fn=<NegBackward0>)
#   395 loss: tensor(2.6130, grad_fn=<NegBackward0>)
#   396 loss: tensor(2.6126, grad_fn=<NegBackward0>)
#   397 loss: tensor(2.6121, grad_fn=<NegBackward0>)
#   398 loss: tensor(2.6116, grad_fn=<NegBackward0>)
#   399 loss: tensor(2.6111, grad_fn=<NegBackward0>)
#   400 loss: tensor(2.6106, grad_fn=<NegBackward0>)
#   401 loss: tensor(2.6102, grad_fn=<NegBackward0>)
#   402 loss: tensor(2.6097, grad_fn=<NegBackward0>)
#   403 loss: tensor(2.6092, grad_fn=<NegBackward0>)
#   404 loss: tensor(2.6087, grad_fn=<NegBackward0>)
#   405 loss: tensor(2.6083, grad_fn=<NegBackward0>)
#   406 loss: tensor(2.6078, grad_fn=<NegBackward0>)
#   407 loss: tensor(2.6073, grad_fn=<NegBackward0>)
#   408 loss: tensor(2.6068, grad_fn=<NegBackward0>)
#   409 loss: tensor(2.6064, grad_fn=<NegBackward0>)
#   410 loss: tensor(2.6059, grad_fn=<NegBackward0>)
#   411 loss: tensor(2.6055, grad_fn=<NegBackward0>)
#   412 loss: tensor(2.6050, grad_fn=<NegBackward0>)
#   413 loss: tensor(2.6045, grad_fn=<NegBackward0>)
#   414 loss: tensor(2.6041, grad_fn=<NegBackward0>)
#   415 loss: tensor(2.6036, grad_fn=<NegBackward0>)
#   416 loss: tensor(2.6032, grad_fn=<NegBackward0>)
#   417 loss: tensor(2.6027, grad_fn=<NegBackward0>)
#   418 loss: tensor(2.6023, grad_fn=<NegBackward0>)
#   419 loss: tensor(2.6018, grad_fn=<NegBackward0>)
#   420 loss: tensor(2.6014, grad_fn=<NegBackward0>)
#   421 loss: tensor(2.6009, grad_fn=<NegBackward0>)
#   422 loss: tensor(2.6005, grad_fn=<NegBackward0>)
#   423 loss: tensor(2.6001, grad_fn=<NegBackward0>)
#   424 loss: tensor(2.5996, grad_fn=<NegBackward0>)
#   425 loss: tensor(2.5992, grad_fn=<NegBackward0>)
#   426 loss: tensor(2.5987, grad_fn=<NegBackward0>)
#   427 loss: tensor(2.5983, grad_fn=<NegBackward0>)
#   428 loss: tensor(2.5979, grad_fn=<NegBackward0>)
#   429 loss: tensor(2.5974, grad_fn=<NegBackward0>)
#   430 loss: tensor(2.5970, grad_fn=<NegBackward0>)
#   431 loss: tensor(2.5966, grad_fn=<NegBackward0>)
#   432 loss: tensor(2.5961, grad_fn=<NegBackward0>)
#   433 loss: tensor(2.5957, grad_fn=<NegBackward0>)
#   434 loss: tensor(2.5953, grad_fn=<NegBackward0>)
#   435 loss: tensor(2.5949, grad_fn=<NegBackward0>)
#   436 loss: tensor(2.5945, grad_fn=<NegBackward0>)
#   437 loss: tensor(2.5940, grad_fn=<NegBackward0>)
#   438 loss: tensor(2.5936, grad_fn=<NegBackward0>)
#   439 loss: tensor(2.5932, grad_fn=<NegBackward0>)
#   440 loss: tensor(2.5928, grad_fn=<NegBackward0>)
#   441 loss: tensor(2.5924, grad_fn=<NegBackward0>)
#   442 loss: tensor(2.5919, grad_fn=<NegBackward0>)
#   443 loss: tensor(2.5915, grad_fn=<NegBackward0>)
#   444 loss: tensor(2.5911, grad_fn=<NegBackward0>)
#   445 loss: tensor(2.5907, grad_fn=<NegBackward0>)
#   446 loss: tensor(2.5903, grad_fn=<NegBackward0>)
#   447 loss: tensor(2.5899, grad_fn=<NegBackward0>)
#   448 loss: tensor(2.5895, grad_fn=<NegBackward0>)
#   449 loss: tensor(2.5891, grad_fn=<NegBackward0>)
#   450 loss: tensor(2.5887, grad_fn=<NegBackward0>)
#   451 loss: tensor(2.5883, grad_fn=<NegBackward0>)
#   452 loss: tensor(2.5879, grad_fn=<NegBackward0>)
#   453 loss: tensor(2.5875, grad_fn=<NegBackward0>)
#   454 loss: tensor(2.5871, grad_fn=<NegBackward0>)
#   455 loss: tensor(2.5867, grad_fn=<NegBackward0>)
#   456 loss: tensor(2.5863, grad_fn=<NegBackward0>)
#   457 loss: tensor(2.5859, grad_fn=<NegBackward0>)
#   458 loss: tensor(2.5855, grad_fn=<NegBackward0>)
#   459 loss: tensor(2.5851, grad_fn=<NegBackward0>)
#   460 loss: tensor(2.5847, grad_fn=<NegBackward0>)
#   461 loss: tensor(2.5843, grad_fn=<NegBackward0>)
#   462 loss: tensor(2.5840, grad_fn=<NegBackward0>)
#   463 loss: tensor(2.5836, grad_fn=<NegBackward0>)
#   464 loss: tensor(2.5832, grad_fn=<NegBackward0>)
#   465 loss: tensor(2.5828, grad_fn=<NegBackward0>)
#   466 loss: tensor(2.5824, grad_fn=<NegBackward0>)
#   467 loss: tensor(2.5820, grad_fn=<NegBackward0>)
#   468 loss: tensor(2.5817, grad_fn=<NegBackward0>)
#   469 loss: tensor(2.5813, grad_fn=<NegBackward0>)
#   470 loss: tensor(2.5809, grad_fn=<NegBackward0>)
#   471 loss: tensor(2.5805, grad_fn=<NegBackward0>)
#   472 loss: tensor(2.5802, grad_fn=<NegBackward0>)
#   473 loss: tensor(2.5798, grad_fn=<NegBackward0>)
#   474 loss: tensor(2.5794, grad_fn=<NegBackward0>)
#   475 loss: tensor(2.5790, grad_fn=<NegBackward0>)
#   476 loss: tensor(2.5787, grad_fn=<NegBackward0>)
#   477 loss: tensor(2.5783, grad_fn=<NegBackward0>)
#   478 loss: tensor(2.5779, grad_fn=<NegBackward0>)
#   479 loss: tensor(2.5776, grad_fn=<NegBackward0>)
#   480 loss: tensor(2.5772, grad_fn=<NegBackward0>)
#   481 loss: tensor(2.5768, grad_fn=<NegBackward0>)
#   482 loss: tensor(2.5765, grad_fn=<NegBackward0>)
#   483 loss: tensor(2.5761, grad_fn=<NegBackward0>)
#   484 loss: tensor(2.5758, grad_fn=<NegBackward0>)
#   485 loss: tensor(2.5754, grad_fn=<NegBackward0>)
#   486 loss: tensor(2.5750, grad_fn=<NegBackward0>)
#   487 loss: tensor(2.5747, grad_fn=<NegBackward0>)
#   488 loss: tensor(2.5743, grad_fn=<NegBackward0>)
#   489 loss: tensor(2.5740, grad_fn=<NegBackward0>)
#   490 loss: tensor(2.5736, grad_fn=<NegBackward0>)
#   491 loss: tensor(2.5733, grad_fn=<NegBackward0>)
#   492 loss: tensor(2.5729, grad_fn=<NegBackward0>)
#   493 loss: tensor(2.5726, grad_fn=<NegBackward0>)
#   494 loss: tensor(2.5722, grad_fn=<NegBackward0>)
#   495 loss: tensor(2.5719, grad_fn=<NegBackward0>)
#   496 loss: tensor(2.5715, grad_fn=<NegBackward0>)
#   497 loss: tensor(2.5712, grad_fn=<NegBackward0>)
#   498 loss: tensor(2.5708, grad_fn=<NegBackward0>)
#   499 loss: tensor(2.5705, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>', '<b>']
    while True:
        sample = network.sample (
            network.tokenizer.stoi[letters[-2]],
            network.tokenizer.stoi[letters[-1]]
        )
        letters.append(network.tokenizer.itos[int(sample)])
        if (letters[-1] == '<b>'):
            break
    
    s = ''.join(letters).replace('<b>', '')
    if s != '':
        print(s)
# Out:
# Bod
# Nagy
# Nagy
# Tis
# Szny
# Tiska
