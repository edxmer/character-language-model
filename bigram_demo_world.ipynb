# %%
from bigram_model.bgn import BigramNetwork

# %%
network = BigramNetwork("data/cities_normalized.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.7227, grad_fn=<NegBackward0>)
#   1 tensor(3.2363, grad_fn=<NegBackward0>)
#   2 tensor(3.0252, grad_fn=<NegBackward0>)
#   3 tensor(2.9132, grad_fn=<NegBackward0>)
#   4 tensor(2.8416, grad_fn=<NegBackward0>)
# 115 tensor(2.6099, grad_fn=<NegBackward0>)
# 116 tensor(2.6093, grad_fn=<NegBackward0>)
# 117 tensor(2.6098, grad_fn=<NegBackward0>)
# 118 tensor(2.6092, grad_fn=<NegBackward0>)
# 119 tensor(2.6097, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>tyaluvamamaipr<b>
# <b>caka<b>
# <b>maumanagovi<b>
# <b>ttaiy<b>
# <b>htooumai<b>
# <b>gorigpenelieno<b>
# <b>titiva<b>
# <b>sttandoja<b>
# <b>basilir<b>
# <b>cun<b>
# <b>o<b>
# <b>dnssta<b>
# <b>hirechid<b>
# <b>psh<b>
# <b>inseraduwi<b>
# <b>vea<b>
# <b>ttkkambhuarolodia<b>
# <b>sav<b>
# <b>kurarirurualelimoned<b>
# <b>n<b>
