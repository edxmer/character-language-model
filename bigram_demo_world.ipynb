# %%
from bigram_model.bgn import BigramNetwork
# Out:
# /Users/edi/dev/ai/character-language-model/.venv/lib/python3.14/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
network = BigramNetwork("data/cities_normalized.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.7909, grad_fn=<NegBackward0>)
#   1 tensor(3.2426, grad_fn=<NegBackward0>)
#   2 tensor(3.0182, grad_fn=<NegBackward0>)
#   3 tensor(2.9005, grad_fn=<NegBackward0>)
#   4 tensor(2.8289, grad_fn=<NegBackward0>)
# 115 tensor(2.6097, grad_fn=<NegBackward0>)
# 116 tensor(2.6091, grad_fn=<NegBackward0>)
# 117 tensor(2.6096, grad_fn=<NegBackward0>)
# 118 tensor(2.6091, grad_fn=<NegBackward0>)
# 119 tensor(2.6095, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>ppercocawiha<b>
# <b>a<b>
# <b>nantahaldetalin<b>
# <b>chqu<b>
# <b>bur<b>
# <b>krgvimishe<b>
# <b>pasa<b>
# <b>mare<b>
# <b>pui<b>
# <b>lmtengelpin<b>
# <b>cuaghnjugate<b>
# <b>uzbdwogon<b>
# <b>gurouiri<b>
# <b>padatavilepa<b>
# <b>mur<b>
# <b>als<b>
# <b>sse<b>
# <b>batrompulilaminadehabutaviarawapopularegryngc<b>
# <b>issy<b>
# <b>fada<b>
