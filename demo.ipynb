# %%
from bgn import BigramNetwork

# %%
network = BigramNetwork("data/cities_normalized.txt", 100)
# Out:
# /Users/edi/dev/ai/bigram-language-model/bgn.py:36: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.W = torch.tensor(torch.randn((self.n, self.n), dtype=torch.float32), requires_grad=True) # nxn

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.7007, grad_fn=<NegBackward0>)
#   1 tensor(3.2491, grad_fn=<NegBackward0>)
#   2 tensor(3.0367, grad_fn=<NegBackward0>)
#   3 tensor(2.9089, grad_fn=<NegBackward0>)
#   4 tensor(2.8340, grad_fn=<NegBackward0>)
# 115 tensor(2.6094, grad_fn=<NegBackward0>)
# 116 tensor(2.6099, grad_fn=<NegBackward0>)
# 117 tensor(2.6093, grad_fn=<NegBackward0>)
# 118 tensor(2.6098, grad_fn=<NegBackward0>)
# 119 tensor(2.6093, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>nahijanichasudsanveysallltunganjuaue<b>
# <b>m<b>
# <b>ranchingonadagala<b>
# <b>bam<b>
# <b>asamr<b>
# <b>chiakolabuitangsilnarsilirmuricwihartenawruch<b>
# <b>bono<b>
# <b>bi<b>
# <b>l<b>
# <b>bonzjodopanaicu<b>
# <b>lighevonjcor<b>
# <b>lanaawaxlpadlyarara<b>
# <b>yshucuqont<b>
# <b>ly<b>
# <b>k<b>
# <b>onararatag<b>
# <b>si<b>
# <b>mouqura<b>
# <b>a<b>
# <b>olsbai<b>
